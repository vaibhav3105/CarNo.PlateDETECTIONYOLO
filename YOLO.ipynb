# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.9/626.9 kB 11.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0bf2fd45f7d1> in <cell line: 1>()
# ----> 1 from ultralytics import YOLO
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
model=YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 224MB/s]

# %%
model.train(data='data.yaml',epochs=50)
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.predict(source='/content/image.jpeg', save=True, conf=0.1)
# Out:
# image 1/1 /content/image.jpeg: 384x640 (no detections), 54.1ms
# Speed: 3.1ms preprocess, 54.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict5
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'License Plate'}
#  orig_img: array([[[184, 165, 160],
#          [191, 177, 171],
#          [221, 212, 208],
#          ...,
#          [231, 234, 239],
#          [190, 193, 198],
#          [152, 155, 160]],
#
#         [[196, 177, 172],
#          [204, 190, 184],
#          [232, 223, 219],
#          ...,
#          [240, 243, 248],
#          [203, 206, 211],
#          [171, 174, 179]],
#
#         [[186, 167, 164],
#          [191, 176, 173],
#          [223, 214, 210],
#          ...,
#          [248, 251, 255],
#          [215, 218, 223],
#          [186, 189, 194]],
#
#         ...,
#
# ...

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 75.3MB/s]

# %%
# !unzip /content/Number_Plate_Large.v1i.yolov8.zip
# Out:
# Archive:  /content/Number_Plate_Large.v1i.yolov8.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/10.rf.4cdc87b3d2d6c90249cb29607b79eae9.jpg
#  extracting: test/images/106.rf.22ecadbdeb4045cdb0f0b79f85a42a81.jpg
#  extracting: test/images/117.rf.775c3a211c1d4c8f7372dcc490a7c32b.jpg
#  extracting: test/images/12.rf.58e55f6c3172317aa39a857d1fc211ce.jpg
#  extracting: test/images/128.rf.42d5ae7b358ec61869f5b9b7d507c9b9.jpg
#  extracting: test/images/13.rf.404141dd39f596fb770c4de7b3ad5585.jpg
#  extracting: test/images/13_jpg.rf.19434c6423d064260c7e0a7f98f6ee61.jpg
#  extracting: test/images/141.rf.cb22581e66066f32dfc5b51f13250891.jpg
#  extracting: test/images/149_jpg.rf.a4257068d2d6e4de92d9994c0e824fae.jpg
#  extracting: test/images/155.rf.2c6cbd5efaf0153c0c11ab67a7c4d331.jpg
#  extracting: test/images/156_jpg.rf.78a57bf0e3d62996b6348ed647a745e8.jpg
# ...

# %%
model.train(data='data.yaml',epochs=10)
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.train(data='data.yaml',epochs=10)
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
